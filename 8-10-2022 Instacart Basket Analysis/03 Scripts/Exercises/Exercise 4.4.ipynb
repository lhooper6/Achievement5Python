# %% [markdown]
# # Exercise 4.4

# %% [markdown]
# 1. Import Libraries/ Data
# 2. Drop Columns
# 3. FInd Missing Data
# 4. Import Departments Data
# 5. Transpose
# 6. Create a Subset for Snacks Section
#
# Task 4.4
# 2. Find identifier variable
# 3. Change the name of eval set
# 4. Frequency of every hour of every day
# 5. Determine meaning of department id 4
# 6. Breakfast Item sales info
# 7. Dinner Party Detials
# 8. Count Rows of Dinner Data Frame
# 12. Export
# 13. Export

# %%
# 1 Import Libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\419182\8-10-2022 Instacart Basket Analysis'

# %%
# Import Orders and Products
df_orders = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), index_col = False)

# %%
df_prods= pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)

# %%
df_orders.shape
# Out:
# (3421083, 7)

# %%
df_prods.shape
# Out:
# (49693, 5)

# %%
#  2 Drop Columns
df_orders.drop(columns = ['eval_set'])
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %%
# 3 Finding Missing Data
df_orders['days_since_prior_order'].value_counts(dropna = False)
# Out:
# 30.0    369323
# 7.0     320608
# 6.0     240013
# 4.0     221696
# 3.0     217005
# 5.0     214503
# NaN     206209
# 2.0     193206
# 8.0     181717
# 1.0     145247
# 9.0     118188
# 14.0    100230
# 10.0     95186
# 13.0     83214
# 11.0     80970
# 12.0     76146
# 0.0      67755
# 15.0     66579
# 16.0     46941
# 21.0     45470
# 17.0     39245
# 20.0     38527
# 18.0     35881
# 19.0     34384
# 22.0     32012
# 28.0     26777
# 23.0     23885
# 27.0     22013
# 24.0     20712
# 25.0     19234
# 29.0     19191
# 26.0     19016
# Name: days_since_prior_order, dtype: int64

# %%
df_orders['order_id'] = df_orders['order_id'].astype('str')

# %%
# change order dow name
df_orders.rename(columns = {'order dow' : 'orders_day_of_week'}, inplace = True)

# %%
#Change data type of order id column so it does not appear in describe
df_orders['order_id'].dtype
# Out:
# dtype('O')

# %%
# 4 Import Departments Data
df_dep = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'departments.csv'), index_col = False)

# %%
df_dep.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
#  5 Transpose 
df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# Overwrite
def_dep_t = df_dep.T

# %%
def_dep_t
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# Add an Index to fix column headers
def_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
# Create an Object of containing first row of the data frame
new_header = def_dep_t.iloc[0]

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
# New data frame that copies rows over rows beyond first row
def_dep_t_new = def_dep_t[1:]

# %%
def_dep_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %%
# set header varaible to header of new data frame
def_dep_t_new.columns = new_header

# %%
def_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
#  Turn new dataframe into a data dictionary
data_dict = def_dep_t_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# find out what what deparmtent id number 19 stands for in data dictionary
print(data_dict.get('19'))
# Out:
# {'department': 'snacks'}

# %%
# 6 Create a subset of the snacks section
df_snacks = df_prods[df_prods['department_id']==19]

# %%
# save to a data frame
df_snacks = df_prods[df_prods['department_id']==19]

# %%
df_snacks.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %% [markdown]
# # Task 4.4

# %%
# 2 Find Identifier Variable that does not need to be in describe
df_orders.head()
# Out:
#   order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0  2539329        1    prior             1          2                  8
# 1  2398795        1    prior             2          3                  7
# 2   473747        1    prior             3          3                 12
# 3  2254736        1    prior             4          4                  7
# 4   431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# 2 Changing the Data Type of the User ID
df_orders['user_id'] = df_orders['user_id'].astype('str')

# %%
# 2 Check
df_orders['user_id'].dtype
# Out:
# dtype('O')

# %%
# 3 Changing the name of eval_set
df_orders.rename(columns = {'eval_set' : 'evaluation_set'}, inplace = True)

# %%
df_orders.head()
# Out:
#   order_id user_id evaluation_set  order_number  order_dow  order_hour_of_day  \
# 0  2539329       1          prior             1          2                  8
# 1  2398795       1          prior             2          3                  7
# 2   473747       1          prior             3          3                 12
# 3  2254736       1          prior             4          4                  7
# 4   431534       1          prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# 4 Frequency of Hour of the Day
df_orders['order_hour_of_day'].value_counts()
# Out:
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: order_hour_of_day, dtype: int64

# %% [markdown]
# The 10 th recorded hour was most frequent

# %%
# 5 Detemine the meaning of 4 in department_id
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %% [markdown]
# 4 equals produce

# %%
# 6 Breakfast Item Sales Info
df_break = df_prods[df_prods['department_id']==14]

# %%
df_break.head()
# Out:
#      product_id                                      product_name  aisle_id  \
# 27           28                                 Wheat Chex Cereal       121
# 33           34                                               NaN       121
# 67           68                           Pancake Mix, Buttermilk       130
# 89           90                                      Smorz Cereal       121
# 210         211  Gluten Free Organic Cereal Coconut Maple Vanilla       130
#
#      department_id  prices
# 27              14    10.1
# 33              14    12.2
# 67              14    13.7
# 89              14     3.9
# 210             14     3.6

# %%
# 7 Dinner Party Details 
df_dinnerp = df_prods.loc[df_prods['department_id'].isin([5,7,12,20])]

# %%
df_dinnerp.head()
# Out:
#     product_id                                    product_name  aisle_id  \
# 2            3            Robust Golden Unsweetened Oolong Tea        94
# 6            7                  Pure Coconut Water With Orange        98
# 9           10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10          11                               Peach Mango Juice        31
# 16          17                               Rendered Duck Fat        35
#
#     department_id  prices
# 2               7     4.5
# 6               7     4.4
# 9               7     8.4
# 10              7     2.8
# 16             12    17.1

# %%
# 8 Count Rows of df_dinnerp
len(df_dinnerp)
# Out:
# 7650

# %%
# 9 User ID 1 Info
df_user1 = df_orders[df_orders['user_id']=='1']

# %%
df_user1.head()
# Out:
#   order_id user_id evaluation_set  order_number  order_dow  order_hour_of_day  \
# 0  2539329       1          prior             1          2                  8
# 1  2398795       1          prior             2          3                  7
# 2   473747       1          prior             3          3                 12
# 3  2254736       1          prior             4          4                  7
# 4   431534       1          prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# Based on the dataframe, there is some missing info.  This user typically orders earlier in the week, but later in the day around once monthly.

# %%
# 12 Export
df_orders.to_csv(os.path.join(path,'02 Data','Prepared Data', 'orders_wrangled.csv'))

# %%
# 13 Export
def_dep_t_new.to_csv(os.path.join(path,'02 Data','Prepared Data', 'departments_wrangled.csv'))
