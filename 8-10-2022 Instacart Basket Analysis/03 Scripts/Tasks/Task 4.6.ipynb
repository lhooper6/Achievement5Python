# %% [markdown]
# # Task 4.6

# %% [markdown]
# 1. Import Libraries
# 3. Import Orders products combined
# 4. Check shape
# 5. determine a suitable way to combine products and orders products combined and combine
# 6. check with merge flag
# 7. export

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %%
# Import Data
path = r'C:\Users\419182\8-10-2022 Instacart Basket Analysis'

# %%
# 3 Import orders products combined  
dforders_products_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
# 4 check shape 
dforders_products_combined.shape
# Out:
# (32434489, 14)

# %%
# Import cleaned products data
df_products_clean = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_cleaned.csv'), index_col = False)

# %%
# 5 determine a suitable way to combine products and orders products combined
dforders_products_combined.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  order_id  user_id evaluation_set  order_number  \
# 0           0             0   2539329        1          prior             1
# 1           0             0   2539329        1          prior             1
# 2           0             0   2539329        1          prior             1
# 3           0             0   2539329        1          prior             1
# 4           0             0   2539329        1          prior             1
#
#    order_dow  order_hour_of_day  days_since_prior_order  prior_order  \
# 0          2                  8                     NaN         True
# 1          2                  8                     NaN         True
# 2          2                  8                     NaN         True
# 3          2                  8                     NaN         True
# 4          2                  8                     NaN         True
#
#    product_id  add_to_cart_order  reordered _merge
# ...

# %%
df_products_clean.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %% [markdown]
# Product id is a shared column between both.

# %%
# 5 Combine 
df_merged = df_products_clean.merge(dforders_products_combined, on = 'product_id', indicator = 'exists')

# %%
df_merged
# Out:
#           Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0                    0           1  Chocolate Sandwich Cookies        61
# 1                    0           1  Chocolate Sandwich Cookies        61
# 2                    0           1  Chocolate Sandwich Cookies        61
# 3                    0           1  Chocolate Sandwich Cookies        61
# 4                    0           1  Chocolate Sandwich Cookies        61
# ...                ...         ...                         ...       ...
# 32404854         49692       49688      Fresh Foaming Cleanser        73
# 32404855         49692       49688      Fresh Foaming Cleanser        73
# 32404856         49692       49688      Fresh Foaming Cleanser        73
# 32404857         49692       49688      Fresh Foaming Cleanser        73
# 32404858         49692       49688      Fresh Foaming Cleanser        73
#
#           department_id  prices  Unnamed: 0_y  Unnamed: 0.1  order_id  \
# ...

# %%
# 6 check with merge flag
df_merged['exists'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: exists, dtype: int64

# %%
df_merged.shape
# Out:
# (32404859, 20)

# %%
dforders_products_combined.shape
# Out:
# (32434489, 14)

# %%
# 7 export
df_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
